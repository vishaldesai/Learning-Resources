# %% [markdown]
# ### We will use Glue metastore in this demo. You will use Databricks' default metastore. If you would like to connect to Glue in your environment, please contact us at <awsbricksters@databricks.com> for assistance. Our SAs will work with you to help you config it.

# %% [markdown]
# # AWS Lakehouse Devday Overview
#
# ### 1. Create Databases in Glue
# ### 2. Lakehouse Overview
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.1: Data Ingestion
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.2: Unified Data Lake
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.3: Data Analytics, BI and AI
# ### 3. Advanced Features

# %% [markdown]
# <img src=https://pages.databricks.com/rs/094-YMS-629/images/Lakehouse.png width=1000px>

# %% [markdown]
# <img src="https://pages.databricks.com/rs/094-YMS-629/images/delta1.png" alt='Delta1' width=1000/>

# %% [markdown]
# <img src="https://pages.databricks.com/rs/094-YMS-629/images/delta2.png" alt='Delta2' width=1000/>

# %% [markdown]
# ###Part 1: [Prep / Clean Up](https://psa-devday.cloud.databricks.com/?o=5859231797432259#notebook/3918139696806341)

# %% [markdown]
# ###Part 2: Lakehouse Overview
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.1: [Data Ingestion](https://psa-devday.cloud.databricks.com/?o=5859231797432259#notebook/3918139696806343/)
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.2: [Unified Data Lake](https://psa-devday.cloud.databricks.com/?o=5859231797432259#notebook/3918139696806358)
# ### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 2.3: [Data Analytics, BI and AI](https://psa-devday.cloud.databricks.com/?o=5859231797432259#notebook/3918139696806368)

# %% [markdown]
# ###Part 3: [Advanced Features](https://psa-devday.cloud.databricks.com/?o=5859231797432259#notebook/3918139696806379)

# %% [markdown]
# ##We encourage you to explore the documentation to learn more about the various features of the Databricks platform and notebooks.
#
# <br />
# * <a href="https://docs.databricks.com/user-guide/index.html" target="_blank">User Guide</a>
# * <a href="https://docs.databricks.com/user-guide/notebooks/index.html" target="_blank">User Guide / Notebooks</a>
# * <a href="https://docs.databricks.com/administration-guide/index.html" target="_blank">Administration Guide</a>
# * <a href="https://docs.databricks.com/api/index.html" target="_blank">REST API</a>
# * <a href="https://docs.databricks.com/release-notes/index.html" target="_blank">Release Notes</a>
# * <a href="https://docs.databricks.com" target="_blank">And much more!</a>
