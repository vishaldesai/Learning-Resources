# %% [markdown]
# # Part 1: Prep/CleanUp

# %%
dbutils.fs.rm('aws-lakehouse-devday/lakehouse', True)
dbutils.fs.mkdirs('aws-lakehouse-devday/lakehouse')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
# %fs cp -r /databricks-datasets/amazon /aws-lakehouse-devday/lakehouse/amazon
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res0: Boolean = true
# </div>

# %%
# %fs cp -r /databricks-datasets/iot /aws-lakehouse-devday/lakehouse/iot
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = true
# </div>

# %%
# %sql
DROP DATABASE IF EXISTS aws_lakehouse_devday CASCADE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE DATABASE aws_lakehouse_devday
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls /aws-lakehouse-devday/lakehouse/amazon
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/aws-lakehouse-devday/lakehouse/amazon/README.md</td><td>README.md</td><td>396</td></tr><tr><td>dbfs:/aws-lakehouse-devday/lakehouse/amazon/data20K/</td><td>data20K/</td><td>0</td></tr><tr><td>dbfs:/aws-lakehouse-devday/lakehouse/amazon/test4K/</td><td>test4K/</td><td>0</td></tr><tr><td>dbfs:/aws-lakehouse-devday/lakehouse/amazon/users/</td><td>users/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls /aws-lakehouse-devday/lakehouse/iot
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/aws-lakehouse-devday/lakehouse/iot/iot_devices.json</td><td>iot_devices.json</td><td>62509052</td></tr></tbody></table></div>
